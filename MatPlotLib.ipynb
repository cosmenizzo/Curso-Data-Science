# %%
year = [1950, 1970, 1990, 2010, 2020, 2030, 2040, 2050]
pop  = [2.519, 3.692, 5.263, 6.972, 7.584, 8.246, 8.850, 9.346]
print(len(year),'x', len(pop))
# Out:
# 8 x 8

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(year,pop)
plt.show()

# %%
plt.scatter(year,pop)
plt.grid(True)
plt.show()

# %%
x = [1, 3, 6, 3, 2, 7, 3, 9, 7, 5, 2, 4]
plt.hist(x, bins=4)
#plt.grid(True)
plt.show()
